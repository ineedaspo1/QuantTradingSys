# %% [markdown]
# ## Correlation - examining overlap features
#     BollBands_<period>..??? How to use??
#     KAMA_<period>
#     MesaAMA_f<fast period>_s<slow period>
#     EMA_<period>
#     SMA_<period>
#     WghtdMA_<period>
#     TripleMA_<period>
#     DblExpMA_<period>
#     InstTrendline
#     Midpoint_<period>
#     Midprice_<period>
#     PSAR_<period>

# %%
# %matplotlib inline

# %%
import json

from Code.lib.plot_utils import PlotUtility
from Code.lib.time_utils import TimeUtility
from Code.lib.retrieve_data import DataRetrieve, ComputeTarget
from Code.lib.candle_indicators import CandleIndicators
from Code.lib.transformers import Transformers
from Code.lib.ta_overlap_studies import TALibOverlapStudies
from Code.lib.model_utils import ModelUtility
from Code.lib.feature_generator import FeatureGenerator
from Code.utilities.stat_tests import stationarity_tests
from Code.lib.config import current_feature, feature_dict
from Code.models import models_utils
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import pandas as pd
import numpy as np
import datetime
from dateutil.relativedelta import relativedelta
import matplotlib.pylab as plt
from pandas.tseries.offsets import BDay
import os.path
import pickle

# %%
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import TimeSeriesSplit
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %% [markdown]
# ### Load issue data and set date range
# Pivot date is last date and time segments calculated by OOS months and IS-OOS ratio

# %%
plotIt = PlotUtility()
timeUtil = TimeUtility()
ct = ComputeTarget()
candle_ind = CandleIndicators()
dSet = DataRetrieve()
taLibOS = TALibOverlapStudies()
transf = Transformers()
modelUtil = ModelUtility()
featureGen = FeatureGenerator()
    
issue = "TLT"
# Set IS-OOS parameters
pivotDate = datetime.date(2018, 4, 2)
is_oos_ratio = 2
oos_months = 4
segments = 2

dataSet = dSet.read_issue_data(issue)

# get first data from loaded data instead of hard coding start date
dataSet = dSet.set_date_range(dataSet, "2014-09-26", pivotDate)

#set beLong level
beLongThreshold = 0.000
dataSet = ct.setTarget(dataSet, "Long", beLongThreshold)
# Out:
# Successfully retrieved data series for TLT

# %% [markdown]
# ### Set features
# Features should be normalized...

# %%
input_dict = {} # initialize
input_dict = {'f1': 
              {'fname' : 'exp_MA', 
               'params' : [25],
               'transform' : ['Normalized', 20]
               },
              'f2': 
              {'fname' : 'simple_MA', 
               'params' : [4],
               'transform' : ['Normalized', 20]
               },
              'f3': 
              {'fname' : 'weighted_MA', 
               'params' : [20],
               'transform' : ['Normalized', 20]
               },
              'f4': 
              {'fname' : 'triple_EMA', 
               'params' : [10],
               'transform' : ['Normalized', 20]
               },
              'f5': 
              {'fname' : 'triangMA', 
               'params' : [2],
               'transform' : ['Normalized', 20]
               },
              'f6': 
              {'fname' : 'dblEMA', 
               'params' : [7],
               'transform' : ['Normalized', 20]
               },
              'f7': 
              {'fname' : 'kaufman_AMA', 
               'params' : [10],
               'transform' : ['Normalized', 20]
               },
              'f8': 
              {'fname' : 'delta_MESA_AMA', 
               'params' : [0.9, 0.1],
               'transform' : ['Normalized', 20]
               },
              'f9': 
              {'fname' : 'inst_Trendline', 
               'params' : [],
               'transform' : ['Normalized', 20]
               },
              'f10': 
              {'fname' : 'mid_point', 
               'params' : [4],
               'transform' : ['Normalized', 20]
               },
              'f11': 
              {'fname' : 'mid_price', 
               'params' : [4],
               'transform' : ['Normalized', 20]
               },
              'f12': 
              {'fname' : 'pSAR', 
               'params' : [10],
               'transform' : ['Normalized', 20]
               }
             }
dataSet2 = featureGen.generate_features(dataSet, input_dict)
# Out:
# f1
# Current feature:  EMA_25
# transform:  ['Normalized', 20]
# f2
# Current feature:  SMA_4
# transform:  ['Normalized', 20]
# f3
# Current feature:  WghtdMA_20
# transform:  ['Normalized', 20]
# f4
# Current feature:  TripleEMA_10
# transform:  ['Normalized', 20]
# f5
# Current feature:  TriangMA_2
# transform:  ['Normalized', 20]
# f6
# Current feature:  DblEMA_7
# transform:  ['Normalized', 20]
# f7
# Current feature:  KAMA_10
# transform:  ['Normalized', 20]
# f8
# Current feature:  DeltaMesaAMA_f0.9_s0.1
# transform:  ['Normalized', 20]
# f9
# Current feature:  InstTrendline
# transform:  ['Normalized', 20]
# f10
# Current feature:  Midpoint_4
# transform:  ['Normalized', 20]
# f11
# Current feature:  Midprice_4
# transform:  ['Normalized', 20]
# f12
# Current feature:  PSAR_10
# transform:  ['Normalized', 20]

# %% [markdown]
# ### Load processing dates for IS and OOS; set start date for model analysis

# %%
# set date splits
isOosDates = timeUtil.is_oos_data_split(issue, pivotDate, is_oos_ratio, oos_months, segments)
dataLoadStartDate = isOosDates[0]
is_start_date = isOosDates[1]
oos_start_date = isOosDates[2]
is_months = isOosDates[3]
is_end_date = isOosDates[4]
oos_end_date = isOosDates[5]

modelStartDate = is_start_date
modelEndDate = modelStartDate + relativedelta(months=is_months)
print("Issue: " + issue)
print("Start date: " + str(modelStartDate) + "  End date: " + str(modelEndDate))


predictor_vars = "Temp holding spot"
# Out:
#                     Segments:  2
#                 IS OOS Ratio:  2
#                   OOS months:  4
#                    IS Months:  8
#               Months to load:  20
#               Data Load Date:  2016-11-02
#               IS Start  Date:  2016-12-02
#               OOS Start Date:  2017-08-02
#                   Pivot Date:  2018-04-02
# Issue: TLT
# Start date: 2016-12-02  End date: 2017-08-02

# %% [markdown]
# ### Split data for analysis and make a copy for Expected Value calcs

# %%
mmData = dataSet[modelStartDate:modelEndDate].copy()
nrows = mmData.shape[0]

# EV related
evData = dataSet[modelStartDate:modelEndDate].copy()

# %% [markdown]
# ### Plot signals

# %%
plot_dict = {}
plot_dict['Issue'] = issue
plot_vars = [k for k,v in feature_dict.items() if v == 'Keep']
plot_dict['Plot_Vars'] = plot_vars
plot_dict['Volume'] = 'Yes'
plotIt.price_Ind_Vol_Plot(plot_dict, mmData)

# %% [markdown]
# ### Select features to drop including OHL, gainAhead, symbol, Date, Close

# %%
col_vals = [k for k,v in feature_dict.items() if v == 'Drop']
to_drop = ['Open','High','Low', 'gainAhead', 'Symbol', 'Date', 'Close', 'beLong', 'Volume']
for x in to_drop:
    col_vals.append(x)
mmData = dSet.drop_columns(mmData, col_vals)

# %%
print(mmData.head())
# Out:
#             EMA_25_Normalized  SMA_4_Normalized  WghtdMA_20_Normalized  \
# 2016-12-02           0.201700          0.392816               0.216122
# 2016-12-05           0.199195          0.297944               0.220549
# 2016-12-06           0.190320          0.139644               0.219685
# 2016-12-07           0.186872          0.087429               0.225293
# 2016-12-08           0.190207          0.062841               0.237237
#
#             TripleEMA_10_Normalized  TriangMA_2_Normalized  \
# 2016-12-02                 0.401508               0.221851
# 2016-12-05                 0.343165               0.112741
# 2016-12-06                 0.228096               0.080392
# 2016-12-07                 0.250053               0.154838
# 2016-12-08                 0.211099               0.157026
#
#             DblEMA_7_Normalized  KAMA_10_Normalized  \
# 2016-12-02             0.371518            0.341458
# 2016-12-05             0.309440            0.352096
# 2016-12-06             0.211004            0.350677
# 2016-12-07             0.234531            0.351635
# 2016-12-08             0.165159            0.362842
#
#             DeltaMesaAMA_f0.9_s0.1_Normalized  InstTrendline_Normalized  \
# 2016-12-02                           0.780127                  0.103340
# 2016-12-05                           0.734119                  0.089669
# 2016-12-06                           0.750446                  0.078501
# 2016-12-07                           0.886189                  0.075297
# 2016-12-08                           0.875290                  0.082303
#
#             Midpoint_4_Normalized  Midprice_4_Normalized  PSAR_10_Normalized
# 2016-12-02               0.392674               0.380828            0.325475
# 2016-12-05               0.312011               0.332235            0.324671
# 2016-12-06               0.155462               0.251412            0.321154
# 2016-12-07               0.110094               0.230458            0.161910
# 2016-12-08               0.108556               0.192152            0.168306

# %% [markdown]
# ### Plot correlation matrix
# Improve this to identify and drop features with corr value higher than 0.3
# Look at other methods to identify features and their contribution

# %%
plotIt.correlation_matrix(mmData)

# %% [markdown]
# #### Examine and drop features with corr value > 0.85

# %%
# Create correlation matrix
corr_matrix = mmData.corr()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
print(upper)

# Find index of feature columns with correlation greater than 0.85
to_drop = [column for column in upper.columns if any(upper[column] > 0.85)]
print("\n=====To Drop=====\n" + str(to_drop))
# Out:
#                                    EMA_25_Normalized  SMA_4_Normalized  \
# EMA_25_Normalized                                NaN          0.772959
# SMA_4_Normalized                                 NaN               NaN
# WghtdMA_20_Normalized                            NaN               NaN
# TripleEMA_10_Normalized                          NaN               NaN
# TriangMA_2_Normalized                            NaN               NaN
# DblEMA_7_Normalized                              NaN               NaN
# KAMA_10_Normalized                               NaN               NaN
# DeltaMesaAMA_f0.9_s0.1_Normalized                NaN               NaN
# InstTrendline_Normalized                         NaN               NaN
# Midpoint_4_Normalized                            NaN               NaN
# Midprice_4_Normalized                            NaN               NaN
# PSAR_10_Normalized                               NaN               NaN
#
#                                    WghtdMA_20_Normalized  \
# EMA_25_Normalized                               0.946922
# SMA_4_Normalized                                0.767334
# WghtdMA_20_Normalized                                NaN
# TripleEMA_10_Normalized                              NaN
# TriangMA_2_Normalized                                NaN
# DblEMA_7_Normalized                                  NaN
# KAMA_10_Normalized                                   NaN
# DeltaMesaAMA_f0.9_s0.1_Normalized                    NaN
# InstTrendline_Normalized                             NaN
# Midpoint_4_Normalized                                NaN
# Midprice_4_Normalized                                NaN
# PSAR_10_Normalized                                   NaN
#
#                                    TripleEMA_10_Normalized  \
# EMA_25_Normalized                                 0.696057
# SMA_4_Normalized                                  0.982626
# WghtdMA_20_Normalized                             0.689731
# TripleEMA_10_Normalized                                NaN
# TriangMA_2_Normalized                                  NaN
# DblEMA_7_Normalized                                    NaN
# KAMA_10_Normalized                                     NaN
# DeltaMesaAMA_f0.9_s0.1_Normalized                      NaN
# InstTrendline_Normalized                               NaN
# Midpoint_4_Normalized                                  NaN
# Midprice_4_Normalized                                  NaN
# PSAR_10_Normalized                                     NaN
#
#                                    TriangMA_2_Normalized  DblEMA_7_Normalized  \
# EMA_25_Normalized                               0.649041             0.718150
# SMA_4_Normalized                                0.950708             0.987398
# WghtdMA_20_Normalized                           0.642478             0.717691
# TripleEMA_10_Normalized                         0.971954             0.998288
# TriangMA_2_Normalized                                NaN             0.973795
# DblEMA_7_Normalized                                  NaN                  NaN
# KAMA_10_Normalized                                   NaN                  NaN
# DeltaMesaAMA_f0.9_s0.1_Normalized                    NaN                  NaN
# InstTrendline_Normalized                             NaN                  NaN
# Midpoint_4_Normalized                                NaN                  NaN
# Midprice_4_Normalized                                NaN                  NaN
# PSAR_10_Normalized                                   NaN                  NaN
#
#                                    KAMA_10_Normalized  \
# EMA_25_Normalized                            0.930729
# SMA_4_Normalized                             0.834197
# WghtdMA_20_Normalized                        0.927648
# TripleEMA_10_Normalized                      0.779695
# TriangMA_2_Normalized                        0.703629
# DblEMA_7_Normalized                          0.794681
# KAMA_10_Normalized                                NaN
# DeltaMesaAMA_f0.9_s0.1_Normalized                 NaN
# InstTrendline_Normalized                          NaN
# Midpoint_4_Normalized                             NaN
# Midprice_4_Normalized                             NaN
# PSAR_10_Normalized                                NaN
#
#                                    DeltaMesaAMA_f0.9_s0.1_Normalized  \
# EMA_25_Normalized                                          -0.007337
# SMA_4_Normalized                                            0.449272
# WghtdMA_20_Normalized                                       0.020108
# TripleEMA_10_Normalized                                     0.538483
# TriangMA_2_Normalized                                       0.550469
# DblEMA_7_Normalized                                         0.519034
# KAMA_10_Normalized                                          0.103101
# DeltaMesaAMA_f0.9_s0.1_Normalized                                NaN
# InstTrendline_Normalized                                         NaN
# Midpoint_4_Normalized                                            NaN
# Midprice_4_Normalized                                            NaN
# PSAR_10_Normalized                                               NaN
#
#                                    InstTrendline_Normalized  \
# EMA_25_Normalized                                  0.649360
# SMA_4_Normalized                                   0.329439
# WghtdMA_20_Normalized                              0.590674
# TripleEMA_10_Normalized                            0.260407
# TriangMA_2_Normalized                              0.254147
# DblEMA_7_Normalized                                0.281936
# KAMA_10_Normalized                                 0.540930
# DeltaMesaAMA_f0.9_s0.1_Normalized                 -0.396290
# InstTrendline_Normalized                                NaN
# Midpoint_4_Normalized                                   NaN
# Midprice_4_Normalized                                   NaN
# PSAR_10_Normalized                                      NaN
#
#                                    Midpoint_4_Normalized  \
# EMA_25_Normalized                               0.772780
# SMA_4_Normalized                                0.993204
# WghtdMA_20_Normalized                           0.768015
# TripleEMA_10_Normalized                         0.975312
# TriangMA_2_Normalized                           0.939651
# DblEMA_7_Normalized                             0.980516
# KAMA_10_Normalized                              0.833495
# DeltaMesaAMA_f0.9_s0.1_Normalized               0.453336
# InstTrendline_Normalized                        0.325373
# Midpoint_4_Normalized                                NaN
# Midprice_4_Normalized                                NaN
# PSAR_10_Normalized                                   NaN
#
#                                    Midprice_4_Normalized  PSAR_10_Normalized
# EMA_25_Normalized                               0.777186            0.838842
# SMA_4_Normalized                                0.986122            0.739796
# WghtdMA_20_Normalized                           0.780650            0.874177
# TripleEMA_10_Normalized                         0.970832            0.663137
# TriangMA_2_Normalized                           0.930673            0.566148
# DblEMA_7_Normalized                             0.976596            0.677941
# KAMA_10_Normalized                              0.845926            0.883215
# DeltaMesaAMA_f0.9_s0.1_Normalized               0.460671            0.014132
# InstTrendline_Normalized                        0.301771            0.513523
# Midpoint_4_Normalized                           0.989754            0.736538
# Midprice_4_Normalized                                NaN            0.747442
# PSAR_10_Normalized                                   NaN                 NaN
#
# =====To Drop=====
# ['WghtdMA_20_Normalized', 'TripleEMA_10_Normalized', 'TriangMA_2_Normalized', 'DblEMA_7_Normalized', 'KAMA_10_Normalized', 'Midpoint_4_Normalized', 'Midprice_4_Normalized', 'PSAR_10_Normalized']
