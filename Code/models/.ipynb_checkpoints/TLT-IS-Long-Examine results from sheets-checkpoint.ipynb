# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
from itertools import count
import seaborn as sns

# %matplotlib inline

# %%
# get list of sheets in each system dir
sheets = glob.glob("TLT-Long-System-*/*.csv")

# %%
all_data = pd.DataFrame()

for i in sheets:
    #print(i)
    df = pd.read_csv(i)
    #print(df)
    all_data = all_data.append(df,ignore_index=True)
    all_data['sys_name'] = i

all_data = all_data.drop(['beLongCount','Rows'],axis=1)

# %%
all_data.describe()
# Out:
#        FeatureCount  IS-Accuracy        IS-EV       IS-MCC       IS-NPV  \
# count   1200.000000  1200.000000  1200.000000  1172.000000  1172.000000
# mean       8.250000     0.792006     0.141135     0.593501     0.803783
# std        0.726595     0.110809     0.055834     0.213282     0.110137
# min        6.000000     0.541667     0.004490     0.057443     0.526316
# 25%        8.000000     0.714678     0.104619     0.435665     0.724278
# 50%        8.000000     0.786111     0.140668     0.580438     0.782366
# 75%        9.000000     0.883333     0.186971     0.770918     0.890191
# max        9.000000     1.000000     0.253324     1.000000     1.000000
#
#        IS-Precision        IS-RF       IS-RMC  OOS-Accuracy       OOS-EV  \
# count   1200.000000  1200.000000  1200.000000   1200.000000  1200.000000
# mean       0.791948     0.208060     0.149154      0.601333     0.051653
# std        0.113611     0.108905     0.082835      0.091070     0.049791
# min        0.436678     0.000000     0.000000      0.450000    -0.040672
# 25%        0.713178     0.116751     0.084211      0.544444     0.012270
# 50%        0.802822     0.197917     0.163158      0.583333     0.046735
# 75%        0.885652     0.289444     0.215789      0.633333     0.075606
# max        1.000000     0.457064     0.311224      0.994444     0.259212
#
#            OOS-MCC      OOS-NPV  OOS-Precision       OOS-RF      OOS-RMC
# count  1176.000000  1176.000000    1200.000000  1200.000000  1200.000000
# mean      0.197020     0.576868       0.627746     0.374076     0.325224
# std       0.185033     0.105173       0.099166     0.090694     0.132866
# min      -0.127431     0.381818       0.412381     0.000000     0.000000
# 25%       0.078645     0.508628       0.561111     0.339370     0.247525
# 50%       0.159941     0.551020       0.617148     0.386578     0.329787
# 75%       0.255272     0.608696       0.669211     0.438889     0.404677
# max       0.988934     1.000000       1.000000     0.520000     0.680851

# %%
pd.isnull(all_data)

# %%
all_data = all_data.dropna(axis = 0, how ='any')

# %%
all_data.shape[0]

# %%
all_data.to_excel("IS_all_data_04052019_v2.xlsx")

# %%
all_data.groupby(["Model"])["IS-Accuracy","OOS-Accuracy"].agg([np.mean, np.std])
# Out:
#        IS-Accuracy           OOS-Accuracy
#               mean       std         mean       std
# Model
# GTB       0.935377  0.020392     0.607417  0.103042
# KNN       0.768112  0.035318     0.569722  0.068305
# LogReg    0.705946  0.056241     0.620556  0.081118
# QDA       0.813492  0.060349     0.594389  0.104492
# RF        0.879179  0.033532     0.620417  0.100243
# SVM       0.667330  0.079669     0.600872  0.077032

# %%
lbl_to_plot = ['IS-Accuracy', 'OOS-Accuracy',
               'IS-MCC', 'OOS-MCC',
               'IS-EV', 'OOS-EV',]

# %%
# index = 0
# while index < len(lbl_to_plot):
#     sns.distplot(all_data[lbl_to_plot[index]], bins=10, color="skyblue", label=str(lbl_to_plot[index]))
#     sns.distplot(all_data[lbl_to_plot[index+1]], bins=10, color="red", label=str(lbl_to_plot[index+1]))
#     index += 2
#     plt.show()

# %%
def h_plot(data, lbls):
    index = 0
    while index < len(lbls):
        plt.hist(data[lbls[index]], bins=20, alpha=0.5, label=str(lbls[index]))
        plt.hist(data[lbls[index+1]], bins=20, alpha=0.5, label=str(lbls[index+1]))
        plt.legend(loc='upper right')
        plt.figsize=(7,6)
        plt.show()
        index += 2

# %%
def bx_plot(data, lbls):
    index = 0
    pos = 0
    f, axes = plt.subplots(3, 2, figsize=(13, 10), sharex=False)
    sns.set(style="whitegrid")
    while index < len(lbls):
        sns.boxplot(x="Model", y=lbls[index], data = data, ax=axes[pos, 0],hue="FeatureCount")
        sns.boxplot(x="Model", y=lbls[index+1], data = data, ax=axes[pos, 1],hue="FeatureCount")
        pos += 1
        index += 2

# %%
def v_plot(data, lbls):
    index = 0
    pos = 0
    f, axes = plt.subplots(3, 2, figsize=(11, 8), sharex=False)
    while index < len(lbls):
        sns.violinplot(x="Model", y=lbls[index], data = data, ax=axes[pos, 0])
        sns.violinplot(x="Model", y=lbls[index+1], data = data, ax=axes[pos, 1])
        pos += 1
        index += 2

# %% [markdown]
# #### Look at results across all data

# %%
h_plot(all_data, lbl_to_plot)

# %%
bx_plot(all_data[all_data["Model"]=='RF'], lbl_to_plot)

# %%
bx_plot(all_data, lbl_to_plot)

# %%
bx_plot(all_data[all_data["FeatureCount"]==6], lbl_to_plot)

# %%
bx_plot(all_data[all_data["FeatureCount"]==7], lbl_to_plot)

# %%
bx_plot(all_data[all_data["FeatureCount"]==8], lbl_to_plot)

# %%
bx_plot(all_data[all_data["FeatureCount"]==9], lbl_to_plot)

# %% [markdown]
# ### Slice data to use various sets of features (6, 7, 8) and exclude KNN, SVM model results

# %%
slim_data = all_data[(all_data.Model != "KNN") & (all_data.Model != "SVM")]

# %%
h_plot(slim_data[slim_data["FeatureCount"]==6], lbl_to_plot)

# %% [markdown]
# #### 6 features

# %%
bx_plot(slim_data[slim_data["FeatureCount"]==6], lbl_to_plot)

# %%
bx_plot(slim_data[slim_data["FeatureCount"]==7], lbl_to_plot)

# %%
bx_plot(slim_data[slim_data["FeatureCount"]==8], lbl_to_plot)

# %% [markdown]
# #### Reduce results with poor results removed

# %%
best_data = all_data[(all_data["OOS-Accuracy"] > 0.5) & (all_data["OOS-MCC"] > 0.0)& (all_data["OOS-EV"] > 0.05)]

# %%
bx_plot(best_data, lbl_to_plot)

# %%
bx_plot(best_data[best_data["FeatureCount"]==6], lbl_to_plot)

# %%
bx_plot(best_data[best_data["FeatureCount"]==7], lbl_to_plot)

# %%
bx_plot(best_data[best_data["FeatureCount"]==8], lbl_to_plot)

# %%
bx_plot(best_data[best_data["FeatureCount"]==9], lbl_to_plot)
