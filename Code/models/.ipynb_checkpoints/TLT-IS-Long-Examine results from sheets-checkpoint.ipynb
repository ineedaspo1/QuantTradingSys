# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
from itertools import count
import seaborn as sns

# %matplotlib inline

# %%
# get list of sheets in each system dir
sheets = glob.glob("TLT-Long-System-*/*.csv")

# %%
all_data = pd.DataFrame()

for i in sheets:
    #print(i)
    df = pd.read_csv(i)
    all_data = all_data.append(df,ignore_index=True)

all_data = all_data.drop(['beLongCount','Rows'],axis=1)

# %%
all_data.describe()
# Out:
#        FeatureCount  IS-Accuracy  IS-Precision      IS-RMC       IS-RF  \
# count    250.000000   250.000000    250.000000  250.000000  250.000000
# mean       6.880000     0.856479      0.849236    0.098103    0.152109
# std        0.516398     0.103818      0.101443    0.087896    0.101193
# min        6.000000     0.675439      0.651100    0.002710    0.015873
# 25%        7.000000     0.744643      0.741267    0.016949    0.079381
# 50%        7.000000     0.889499      0.880810    0.076677    0.121451
# 75%        7.000000     0.935785      0.923000    0.169329    0.259494
# max        8.000000     0.988000      0.985000    0.328814    0.348790
#
#            IS-NPV      IS-MCC       IS-EV  OOS-Accuracy  OOS-Precision  \
# count  250.000000  250.000000  250.000000    250.000000     250.000000
# mean     0.872114    0.711288    0.175434      0.540744       0.573205
# std      0.108526    0.209810    0.052185      0.066985       0.078223
# min      0.660714    0.349435    0.067746      0.450000       0.458550
# 25%      0.750000    0.487034    0.125237      0.485714       0.506398
# 50%      0.899829    0.780784    0.190430      0.521429       0.545354
# 75%      0.975817    0.871911    0.218759      0.585714       0.629150
# max      0.997159    0.975444    0.253282      0.771000       0.839000
#
#           OOS-RMC      OOS-RF     OOS-NPV     OOS-MCC      OOS-EV
# count  250.000000  250.000000  250.000000  250.000000  250.000000
# mean     0.335929    0.434688    0.474020    0.054937    0.017301
# std      0.127459    0.074712    0.135779    0.153260    0.042494
# min      0.075949    0.159000    0.125000   -0.154266   -0.045903
# 25%      0.227848    0.383601    0.440000   -0.046000   -0.022420
# 50%      0.346942    0.454545    0.482759    0.008803    0.005000
# 75%      0.443038    0.494818    0.539615    0.159894    0.049715
# max      0.619718    0.533333    0.722222    0.549000    0.153000

# %%
all_data.groupby(["Model"])["IS-Accuracy","OOS-Accuracy"].agg([np.mean, np.std])
# Out:
#       IS-Accuracy           OOS-Accuracy
#              mean       std         mean       std
# Model
# GTB      0.922026  0.020971     0.571547  0.064972
# KNN      0.732639  0.016524     0.479947  0.009491
# QDA      0.747639  0.053679     0.558051  0.071261
# RF       0.893554  0.019769     0.590163  0.064048
# SVM      0.986538  0.001198     0.504013  0.019876

# %%
#all_data.to_excel("all_data_03142019.xlsx")

# %%
lbl_to_plot = ['IS-Accuracy', 'OOS-Accuracy',
               'IS-MCC', 'OOS-MCC',
               'IS-EV', 'OOS-EV',]

# %%
# index = 0
# while index < len(lbl_to_plot):
#     sns.distplot(all_data[lbl_to_plot[index]], bins=10, color="skyblue", label=str(lbl_to_plot[index]))
#     sns.distplot(all_data[lbl_to_plot[index+1]], bins=10, color="red", label=str(lbl_to_plot[index+1]))
#     index += 2
#     plt.show()

# %%
def h_plot(data, lbls):
    index = 0
    while index < len(lbls):
        plt.hist(data[lbls[index]], bins=20, alpha=0.5, label=str(lbls[index]))
        plt.hist(data[lbls[index+1]], bins=20, alpha=0.5, label=str(lbls[index+1]))
        plt.legend(loc='upper right')
        plt.figsize=(7,6)
        plt.show()
        index += 2

# %%
def bx_plot(data, lbls):
    index = 0
    pos = 0
    f, axes = plt.subplots(3, 2, figsize=(12, 9), sharex=False)
    while index < len(lbls):
        sns.boxplot(x="Model", y=lbls[index], data = data, ax=axes[pos, 0])
        sns.boxplot(x="Model", y=lbls[index+1], data = data, ax=axes[pos, 1])
        pos += 1
        index += 2

# %% [markdown]
# #### Look at results across all data

# %%
h_plot(all_data, lbl_to_plot)

# %%
bx_plot(all_data, lbl_to_plot)

# %% [markdown]
# ### Slice data to use various sets of features (6, 7, 8) and exclude KNN, SVM model results

# %%
slim_data = all_data[(all_data.Model != "KNN") & (all_data.Model != "SVM")]

# %%
h_plot(slim_data[slim_data["FeatureCount"]==6], lbl_to_plot)

# %% [markdown]
# #### 6 features

# %%
bx_plot(slim_data[slim_data["FeatureCount"]==6], lbl_to_plot)

# %%
bx_plot(slim_data[slim_data["FeatureCount"]==7], lbl_to_plot)

# %%
bx_plot(slim_data[slim_data["FeatureCount"]==8], lbl_to_plot)
